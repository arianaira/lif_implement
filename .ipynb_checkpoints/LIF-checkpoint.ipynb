# %% [markdown]
# # Computational Neuroscience
# ## First serie exercise
# Autor : Ariana Aghamohamadi, student ID: 400222006

# %% [markdown]
# Task Explain :
# in this notebook first we implement LIF class with parameters R and tau and other necessary functions then we create three current dataset varyin in intensity so we can compare their rating spikes and voltage.
# then we test this witt a random current dataset.
# and then we test it with five different models varying in their parameters to compare the results based on parameter change.

# %%
# importing necessary libraries
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### preparing necessary classes

# %%
# defining current dataset class so we can input any current to our model
class CurrentDataset(torch.utils.data.Dataset):
    def __init__(self, df):
        self.data = df

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        sample = self.data.loc[idx].values
        return torch.tensor(sample)

# %%
#defining LIF class
class LIF(torch.nn.Module):
    def __init__(self, R, tau, u_rest, threshold):
        super(LIF, self).__init__()
        self.R = R
        self.tau = tau
        self.u = u_rest
        self.u_rest = u_rest
        self.threshold = threshold
        self.time = 0
        self.history = torch.tensor([self.time,self.u])
    
    def forward(self, x):
        dt = x[0] - self.time
        self.time = x[0]
        
        # calculating du from the equation du = dt * (-(u - u_rest) + RI(t)) / tau
        du = dt * (-1 * (self.u-self.u_rest) + self.R * x[1]) / self.tau
        self.u += du
        
        #checking if u reached the threshold
        if self.u > self.threshold:
            self.to_rest()
            self.history = torch.vstack((self.history,torch.tensor([self.time, self.u])))
            return torch.tensor([[self.time, 1]])
        else : 
            self.history = torch.vstack((self.history,torch.tensor([self.time, self.u])))
            return torch.tensor([[self.time, 0]])
    
    #reseting the model
    def reset(self):
        self.u = self.u_rest
        self.time = 0
        self.history = torch.tensor([self.time, self.u])
        
    # when u reaches the threshold it needs to be back to rest potential
    def to_rest(self):
        self.u = self.u_rest

# %%
#filtering current data that would lead to spikes:
def process(model, currents):
    spikes_data = None 
    for data in currents:
        result = model(data[0])
        if spikes_data is None:
            spikes_data = result
        else : 
            spikes_data = torch.vstack((spikes_data, result))
    return spikes_data

# %% [markdown]
# ### plotting functions

# %%
def plot_currents(df_1, df_2, df_):
    plt.figure(figsize=(8, 3))
    df_1['current'].plot(label='current_1', color='orange')
    df_2['current'].plot(label='current_2', color='b')
    df_3['current'].plot(label='current_3', color='g')
    plt.title('Currents')

    plt.xlabel('time')
    plt.ylabel('I(t)')

    plt.legend()

# %%
def plot_spikes(spikes):
    spike_points = spikes[spikes[:,1]==1.0]
    fig = plt.figure(figsize=(8, 3))
    plt.scatter(spike_points[:,0],spike_points[:,1],marker='|',c='r',s=500)
    plt.xlabel("time (mS)")
    plt.yticks(ticks=[1],labels=['spike'])
    plt.grid()
    plt.title("Spike points diagram")
    plt.show()

# %%
def plot_history(history):
    fig = plt.figure(figsize=(8,3))
    plt.plot(history[:,0],history[:,1],c='g')
    plt.xlabel("time (mS)")
    plt.ylabel("Voltage(mV)")
    plt.grid()
    plt.title("PSP diagram")
    plt.show()

# %% [markdown]
# ## Part a and b :
# indicate different currents, their frequency and voltage.

# %%
# Initializing LIF model with arbitrary values for given parameters
R = 0.1 
tau = 80
u_rest = -65
threshold = -50

lif = LIF(R, tau, u_rest, threshold)

# %%
# creating 3 current datasets
time_steps = 1000
current_1 = np.zeros(time_steps)
time = np.linspace(0, time_steps, time_steps, endpoint=False)
df_1 = pd.DataFrame({'time': pd.Series(time)})
current_1[100:1000] = 200
df_1['current'] = current_1

df_2 = pd.DataFrame({'time': pd.Series(time)})
current_2 = np.zeros(time_steps)
current_2[200:1000] = 300
df_2['current'] = current_2

current_3 = np.zeros(time_steps)
df_3 = pd.DataFrame({'time': pd.Series(time)})
current_3[300:1000] = 400
df_3['current'] = current_3

# %% [markdown]
# ### plotting :

# %%
plot_currents(df_1, df_2, df_3)

# %%
# first current data
dataset_1 = CurrentDataset(df_1)
dataloader_1 = torch.utils.data.DataLoader(dataset_1, batch_size=1, shuffle=False)
spikes_1 = process(lif, dataloader_1)
plot_spikes(spikes_1)

# %%
plot_history(lif.history)

# %%
# second current data
lif.reset()
dataset_2 = CurrentDataset(df_2)
dataloader_2 = torch.utils.data.DataLoader(dataset_2, batch_size=1, shuffle=False)
spikes_2 = process(lif, dataloader_2)
plot_spikes(spikes_2)

# %%
plot_history(lif.history)

# %%
#third current data
lif.reset()
dataset_3 = CurrentDataset(df_3)
dataloader_3 = torch.utils.data.DataLoader(dataset_3, batch_size=1, shuffle=False)
spikes_3 = process(lif, dataloader_3)
plot_spikes(spikes_3)

# %%
plot_history(lif.history)

# %%
# comaring frequency of currents which is number of spikes per small period of time
freq = []
freq_2 = []
freq_3 = []
count = 0
sum = torch.tensor([0])
for i in spikes_1:
    sum = torch.add(i[1] , sum)
    count += 1
    if count == 200:
        freq.append(sum)
        count = 0
        sum = torch.tensor([0])
        
count = 0
sum = torch.tensor([0])
for i in spikes_2:
    sum = torch.add(i[1] , sum)
    count += 1
    if count == 200:
        freq_2.append(sum)
        count = 0
        sum = torch.tensor([0])
        
count = 0
sum = torch.tensor([0])
for i in spikes_3:
    sum = torch.add(i[1] , sum)
    count += 1
    if count == 200:
        freq_3.append(sum)
        count = 0
        sum = torch.tensor([0])
plt.plot(freq, label='current_1')
plt.plot(freq_2, label='current_1')
plt.plot(freq_3, label='current_1')
plt.title('Frequency and current relation')
plt.xlabel('I(t)')
plt.ylabel('frequency')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# as we can see higher I(t) would create higher frequency

# %% [markdown]
# ## Part c :
# test all of the above features with a random current dataset

# %%
lif.reset()
rand = pd.read_csv('random_current.csv')
rand = rand[:1000]

# %%
plt.plot(rand, color='aqua')
plt.title('Random  current')
plt.xlabel('time')
plt.ylabel('I(t)')
# Out:
# Text(0, 0.5, 'I(t)')

# %%
# Spike diagram
dataset = CurrentDataset(rand)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=False)
spikes = process(lif, dataloader)
plot_spikes(spikes_3)

# %%
# Voltage diagram
plot_history(lif.history)

# %% [markdown]
# ## Part d:
# Examining 5 diffrenet models which their parameters are changed
# all with input current_1

# %%
#increasing tau
lif.reset()
R = 0.1 
tau = 100
u_rest = -65
threshold = -50
lif = LIF(R, tau, u_rest, threshold)
spikes_1_1 = process(lif, dataloader_1)
plot_spikes(spikes_1_1)
plot_history(lif.history)

# %%
# Increasing R
lif.reset()
R = 1 
tau = 80
u_rest = -65
threshold = -50
lif = LIF(R, tau, u_rest, threshold)
spikes_1_1 = process(lif, dataloader_1)
plot_spikes(spikes_1_1)
plot_history(lif.history)

# %%
# Icreasing R and tau
lif.reset()
R = 1 
tau = 800
u_rest = -65
threshold = -50
lif = LIF(R, tau, u_rest, threshold)
spikes_1_1 = process(lif, dataloader_1)
plot_spikes(spikes_1_1)
plot_history(lif.history)

# %%
# Decreasing tau 
lif.reset()
R = 0.1 
tau = 8
u_rest = -65
threshold = -50
lif = LIF(R, tau, u_rest, threshold)
spikes_1_1 = process(lif, dataloader_1)
plot_spikes(spikes_1_1)
plot_history(lif.history)

# %%
# Decreasing R
lif.reset()
R = 0.09 
tau = 80
u_rest = -65
threshold = -50
lif = LIF(R, tau, u_rest, threshold)
spikes_1_1 = process(lif, dataloader_1)
plot_spikes(spikes_1_1)
plot_history(lif.history)

# %% [markdown]
#  ## Part e: Analysis

# %% [markdown]
# 1-in the first section we implemented LIF class knowing that each LIF model should have a resting potential and threshold potenial , parameter values of R and $\tau$ and input of any kind of current. we implemented forward method based this equation : $du = dt * (-(u - u_rest) + RI(t))$ and then we started testing our model with 3 levels of intensity of a current.

# %% [markdown]
# 2-we could see from part a and b that higher intensity in electrical current would result in higher frequency this mean that we have more spikes per a period of time which we can see also from voltage plot of each current that each triangle (the space between each two resting potential) is thiner as the intesity of the current gets larger.

# %% [markdown]
# 3-part c indicates that even we have a random current data that is an indication of the firing of multiple presynaptic neurons, form of voltage plot would in general stay the same, it goes from a resting potential to another, only the paths gets wavier.

# %% [markdown]
# 4-part d which was about testing models with different parameters shows us the effect of each one of the parameters (R and $\tau$) on frequency rate. by comparing resulting plots with current_1 plots on a and b part we understand increasing R would result in a larger frequency and a larger $\tau$ would result in a smaller frequency so if we increase both R and $\tau$ the frequency would approximatly stay the same and vice versa.
